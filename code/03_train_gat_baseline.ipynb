# %%
from pathlib import Path
import json
import csv
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
from sklearn.metrics import roc_auc_score, average_precision_score

# %%
from torch_geometric.nn import GATConv

# %%
def ensure_dir(path: Path):
    path.mkdir(parents=True, exist_ok=True)

def load_yaml(path: Path):
    import yaml
    with open(path, "r", encoding="utf-8") as f:
        return yaml.safe_load(f)

def find_project_root(start: Path = None) -> Path:
    if start is None:
        start = Path.cwd()
    for p in [start] + list(start.parents):
        if (p / "code").exists() and (p / "data").exists():
            return p
    return start

project_root = find_project_root()
project_root
# Out:
# WindowsPath('D:/Shiraz University/HomeWorks/Ostad Moosavi/LinkPrediction')

# %%
def set_seed(seed: int = 42):
    import random, os
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
config_path = project_root / "code" / "config.yaml"
cfg = load_yaml(config_path)

set_seed(cfg.get("seed", 42))

proc_dir = project_root / cfg["data"]["processed_dir"]
out_dir  = project_root / cfg["output"]["dir"]

ensure_dir(out_dir / "models")
ensure_dir(out_dir / "logs")

print("proc_dir:", proc_dir)
print("out_dir :", out_dir)
# Out:
# proc_dir: D:\Shiraz University\HomeWorks\Ostad Moosavi\LinkPrediction\data\processed
# out_dir : D:\Shiraz University\HomeWorks\Ostad Moosavi\LinkPrediction\output

# %%
g = torch.load(proc_dir / "graph_edges.pt")
edge_index = g["edge_index"]
num_nodes  = int(g["num_nodes"])

keep_idx = np.load(proc_dir / "train_graph_edge_idx.npy")

splits = np.load(proc_dir / "split_target_edges.npz")
train_pos = splits["train_pos"]
val_pos   = splits["val_pos"]

negs = np.load(proc_dir / "negatives.npz", allow_pickle=True)
val_neg = negs["val_neg"]

print("edge_index:", edge_index.shape)
print("num_nodes:", num_nodes)
print("train_pos:", train_pos.shape, "val_pos:", val_pos.shape)
print("val_neg:", val_neg.shape)
# Out:
# edge_index: torch.Size([2, 118308])
# num_nodes: 37614
# train_pos: (2, 299) val_pos: (2, 37)
# val_neg: (2, 1850)

# %%
keep_idx_t = torch.tensor(keep_idx, dtype=torch.long)
ei_train = edge_index[:, keep_idx_t]

print("ei_train:", ei_train.shape)
# Out:
# ei_train: torch.Size([2, 118233])

# %%
def build_pair_set(heads, tails):
    return set(zip(heads, tails))

def sample_negatives_on_the_fly(batch_heads, tail_candidates, existing_pairs_set,
                               num_negs_per_pos=1, seed=0):
    import random
    rng = random.Random(seed)
    tail_candidates = list(tail_candidates)

    neg_h, neg_t = [], []
    for h in batch_heads:
        for _ in range(num_negs_per_pos):
            for _try in range(30):
                t2 = rng.choice(tail_candidates)
                if (h, t2) not in existing_pairs_set:
                    neg_h.append(h)
                    neg_t.append(t2)
                    break
            else:
                t2 = rng.choice(tail_candidates)
                neg_h.append(h)
                neg_t.append(t2)
    return neg_h, neg_t

tail_candidates = set(val_neg[1].tolist())
existing_pairs = build_pair_set(train_pos[0], train_pos[1])

print("num tail candidates:", len(tail_candidates))
print("num existing train pairs:", len(existing_pairs))
# Out:
# num tail candidates: 1175
# num existing train pairs: 299

# %%
class GATEncoder(nn.Module):
    def __init__(self, num_nodes, dim, heads=4, dropout=0.2):
        super().__init__()
        self.emb = nn.Embedding(num_nodes, dim)
        self.conv1 = GATConv(dim, dim, heads=heads, dropout=dropout, concat=True)
        self.conv2 = GATConv(dim * heads, dim, heads=1, dropout=dropout, concat=False)
        self.dropout = dropout

    def forward(self, edge_index):
        x = self.emb.weight
        x = self.conv1(x, edge_index)
        x = F.elu(x)
        x = F.dropout(x, p=self.dropout, training=self.training)
        x = self.conv2(x, edge_index)
        return x

class MLPLinkScorer(nn.Module):
    def __init__(self, dim, hidden=128, dropout=0.2):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(dim * 3, hidden),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(hidden, 1)
        )

    def forward(self, h_u, h_v):
        x = torch.cat([h_u, h_v, h_u * h_v], dim=-1)
        return self.net(x).squeeze(-1)

def batch_score(node_emb, heads, tails, scorer):
    h_u = node_emb[heads]
    h_v = node_emb[tails]
    return scorer(h_u, h_v)

# %%
def binary_metrics(y_true, y_score):
    y_true = np.asarray(y_true).astype(int)
    y_score = np.asarray(y_score).astype(float)

    out = {}
    try:
        out["roc_auc"] = float(roc_auc_score(y_true, y_score))
        out["pr_auc"]  = float(average_precision_score(y_true, y_score))
    except Exception:
        out["roc_auc"] = None
        out["pr_auc"]  = None

    y_pred = (y_score >= 0).astype(int)  # threshold روی 0 (logit)
    out["accuracy@0"] = float((y_pred == y_true).mean())
    return out

def eval_binary(encoder, scorer, edge_index, pos, neg, device):
    encoder.eval()
    scorer.eval()
    with torch.no_grad():
        z = encoder(edge_index)

        pos_h = torch.tensor(pos[0], dtype=torch.long, device=device)
        pos_t = torch.tensor(pos[1], dtype=torch.long, device=device)
        neg_h = torch.tensor(neg[0], dtype=torch.long, device=device)
        neg_t = torch.tensor(neg[1], dtype=torch.long, device=device)

        pos_logits = batch_score(z, pos_h, pos_t, scorer).detach().cpu().numpy()
        neg_logits = batch_score(z, neg_h, neg_t, scorer).detach().cpu().numpy()

        y_true = np.concatenate([np.ones_like(pos_logits), np.zeros_like(neg_logits)])
        y_score = np.concatenate([pos_logits, neg_logits])

        return binary_metrics(y_true, y_score)

# %%
dim = cfg["model"]["dim"]
heads = cfg["model"].get("gat_heads", 4)
dropout = cfg["model"].get("dropout", 0.2)

encoder = GATEncoder(num_nodes, dim=dim, heads=heads, dropout=dropout)
scorer  = MLPLinkScorer(dim=dim, hidden=cfg["model"].get("mlp_hidden", 128), dropout=dropout)

device = torch.device("cuda" if torch.cuda.is_available() and cfg["train"].get("use_cuda", True) else "cpu")
encoder.to(device)
scorer.to(device)

ei_train = ei_train.to(device)

print("device:", device)
# Out:
# device: cpu

# %%
lr = cfg["train"].get("lr", 1e-3)
epochs = cfg["train"].get("epochs", 20)
batch_size = cfg["train"].get("batch_size", 2048)
neg_per_pos = cfg["train"].get("num_negs_per_pos_train", 1)

opt = torch.optim.Adam(list(encoder.parameters()) + list(scorer.parameters()), lr=lr)

log_path = out_dir / "logs" / "gat_train.csv"
with open(log_path, "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(["epoch", "loss", "val_roc_auc", "val_pr_auc", "val_acc@0"])

best_auc = -1.0
best_path = out_dir / "models" / "gat.pt"

print("log_path:", log_path)
print("best_path:", best_path)
# Out:
# log_path: D:\Shiraz University\HomeWorks\Ostad Moosavi\LinkPrediction\output\logs\gat_train.csv
# best_path: D:\Shiraz University\HomeWorks\Ostad Moosavi\LinkPrediction\output\models\gat.pt

# %%
train_heads = train_pos[0].tolist()

for epoch in range(1, epochs + 1):
    encoder.train()
    scorer.train()

    idx = np.random.permutation(len(train_heads))
    total_loss = 0.0
    n_batches = 0

    for start in range(0, len(idx), batch_size):
        batch_idx = idx[start:start+batch_size]

        bh = train_pos[0][batch_idx].tolist()
        bt = train_pos[1][batch_idx].tolist()

        # negative sampling (corrupt tails)
        nh, nt = sample_negatives_on_the_fly(
            bh, tail_candidates, existing_pairs,
            num_negs_per_pos=neg_per_pos,
            seed=cfg.get("seed", 42) + epoch + start
        )

        bh_t = torch.tensor(bh, dtype=torch.long, device=device)
        bt_t = torch.tensor(bt, dtype=torch.long, device=device)
        nh_t = torch.tensor(nh, dtype=torch.long, device=device)
        nt_t = torch.tensor(nt, dtype=torch.long, device=device)

        opt.zero_grad()

        z = encoder(ei_train)

        pos_logits = batch_score(z, bh_t, bt_t, scorer)
        neg_logits = batch_score(z, nh_t, nt_t, scorer)

        y = torch.cat([torch.ones_like(pos_logits), torch.zeros_like(neg_logits)])
        logits = torch.cat([pos_logits, neg_logits])

        loss = F.binary_cross_entropy_with_logits(logits, y)
        loss.backward()
        opt.step()

        total_loss += float(loss.item())
        n_batches += 1

    avg_loss = total_loss / max(1, n_batches)

    # validation
    val_m = eval_binary(encoder, scorer, ei_train, val_pos, val_neg, device)
    val_auc = val_m.get("roc_auc") if val_m.get("roc_auc") is not None else -1.0

    with open(log_path, "a", newline="", encoding="utf-8") as f:
        writer = csv.writer(f)
        writer.writerow([epoch, avg_loss, val_m.get("roc_auc"), val_m.get("pr_auc"), val_m.get("accuracy@0")])

    print(f"[GAT] epoch={epoch} loss={avg_loss:.4f} val_roc_auc={val_auc}")

    # save best
    if val_auc > best_auc:
        best_auc = val_auc
        torch.save(
            {"encoder": encoder.state_dict(), "scorer": scorer.state_dict(), "cfg": cfg},
            best_path
        )

print(f"[GAT] Done. Best val roc_auc={best_auc:.4f}, saved: {best_path}")
# Out:
# [GAT] epoch=1 loss=0.7034 val_roc_auc=0.5186267348429511
# [GAT] epoch=2 loss=0.6924 val_roc_auc=0.533864134404675
# [GAT] epoch=3 loss=0.6869 val_roc_auc=0.535836376917458
# [GAT] epoch=4 loss=0.6798 val_roc_auc=0.5401168736303872
# [GAT] epoch=5 loss=0.6668 val_roc_auc=0.541709276844412
# [GAT] epoch=6 loss=0.6687 val_roc_auc=0.5472899926953981
# [GAT] epoch=7 loss=0.6457 val_roc_auc=0.5522132943754565
# [GAT] epoch=8 loss=0.6401 val_roc_auc=0.559035792549306
# [GAT] epoch=9 loss=0.6338 val_roc_auc=0.563754565376187
# [GAT] epoch=10 loss=0.6226 val_roc_auc=0.5697589481373265
# [GAT] epoch=11 loss=0.6023 val_roc_auc=0.5746530314097882
# [GAT] epoch=12 loss=0.6186 val_roc_auc=0.5703140978816654
# [GAT] epoch=13 loss=0.5797 val_roc_auc=0.5657852447041636
# [GAT] epoch=14 loss=0.5799 val_roc_auc=0.5613294375456538
# [GAT] epoch=15 loss=0.5595 val_roc_auc=0.5553250547845142
# [GAT] epoch=16 loss=0.5923 val_roc_auc=0.5496712929145362
# [GAT] epoch=17 loss=0.5565 val_roc_auc=0.5470562454346238
# [GAT] epoch=18 loss=0.5478 val_roc_auc=0.5429218407596785
# [GAT] epoch=19 loss=0.5260 val_roc_auc=0.5411395178962747
# [GAT] epoch=20 loss=0.5125 val_roc_auc=0.5372242512783054
# [GAT] epoch=21 loss=0.5075 val_roc_auc=0.5370635500365231
# [GAT] epoch=22 loss=0.5181 val_roc_auc=0.5386267348429511
# [GAT] epoch=23 loss=0.4858 val_roc_auc=0.5402191380569759
# [GAT] epoch=24 loss=0.4762 val_roc_auc=0.5435062089116143
# [GAT] epoch=25 loss=0.5100 val_roc_auc=0.54899926953981
# [GAT] epoch=26 loss=0.4418 val_roc_auc=0.5534112490869247
# [GAT] epoch=27 loss=0.4604 val_roc_auc=0.5565230094959825
# [GAT] epoch=28 loss=0.4388 val_roc_auc=0.5615485756026297
# [GAT] epoch=29 loss=0.4651 val_roc_auc=0.564236669101534
# [GAT] epoch=30 loss=0.4456 val_roc_auc=0.5667932797662527
# [GAT] epoch=31 loss=0.4350 val_roc_auc=0.5686048210372535
# [GAT] epoch=32 loss=0.4169 val_roc_auc=0.5694521548575603
# [GAT] epoch=33 loss=0.3819 val_roc_auc=0.5709276844411979
# [GAT] epoch=34 loss=0.3930 val_roc_auc=0.5722132943754565
# [GAT] epoch=35 loss=0.4127 val_roc_auc=0.5739956172388605
# [GAT] epoch=36 loss=0.3535 val_roc_auc=0.5739225712198686
# [GAT] epoch=37 loss=0.3991 val_roc_auc=0.5732651570489408
# [GAT] epoch=38 loss=0.3586 val_roc_auc=0.5722571219868517
# [GAT] epoch=39 loss=0.4286 val_roc_auc=0.572081811541271
# [GAT] epoch=40 loss=0.3547 val_roc_auc=0.5714828341855368
# [GAT] epoch=41 loss=0.3603 val_roc_auc=0.5717896274653032
# [GAT] epoch=42 loss=0.3431 val_roc_auc=0.5742731921110299
# [GAT] epoch=43 loss=0.3668 val_roc_auc=0.5770197224251278
# [GAT] epoch=44 loss=0.3329 val_roc_auc=0.5791672753834917
# [GAT] epoch=45 loss=0.3291 val_roc_auc=0.5817677136596056
# [GAT] epoch=46 loss=0.3174 val_roc_auc=0.5843827611395178
# [GAT] epoch=47 loss=0.3312 val_roc_auc=0.5871877282688094
# [GAT] epoch=48 loss=0.3229 val_roc_auc=0.5905332359386415
# [GAT] epoch=49 loss=0.2922 val_roc_auc=0.5942439737034332
# [GAT] epoch=50 loss=0.3195 val_roc_auc=0.5979108838568298
# [GAT] epoch=51 loss=0.3148 val_roc_auc=0.6020014609203799
# [GAT] epoch=52 loss=0.3125 val_roc_auc=0.6067786705624544
# [GAT] epoch=53 loss=0.2987 val_roc_auc=0.6119649379108838
# [GAT] epoch=54 loss=0.2935 val_roc_auc=0.6138056975894814
# [GAT] epoch=55 loss=0.2822 val_roc_auc=0.6144631117604091
# [GAT] epoch=56 loss=0.2471 val_roc_auc=0.6136303871439007
# [GAT] epoch=57 loss=0.2563 val_roc_auc=0.6132943754565376
# [GAT] epoch=58 loss=0.2705 val_roc_auc=0.6128560993425858
# [GAT] epoch=59 loss=0.2493 val_roc_auc=0.6140540540540541
# [GAT] epoch=60 loss=0.2223 val_roc_auc=0.6145069393718042
# [GAT] epoch=61 loss=0.2795 val_roc_auc=0.6140832724616508
# [GAT] epoch=62 loss=0.2748 val_roc_auc=0.6119649379108838
# [GAT] epoch=63 loss=0.2745 val_roc_auc=0.6120087655222791
# [GAT] epoch=64 loss=0.2585 val_roc_auc=0.6119357195032871
# [GAT] epoch=65 loss=0.2594 val_roc_auc=0.6116289262235208
# [GAT] epoch=66 loss=0.2641 val_roc_auc=0.6131044558071584
# [GAT] epoch=67 loss=0.2748 val_roc_auc=0.613382030679328
# [GAT] epoch=68 loss=0.2733 val_roc_auc=0.6138787436084734
# [GAT] epoch=69 loss=0.2601 val_roc_auc=0.6149744338933528
# [GAT] epoch=70 loss=0.2545 val_roc_auc=0.615427319211103
# [GAT] epoch=71 loss=0.2402 val_roc_auc=0.6149306062819577
# [GAT] epoch=72 loss=0.2306 val_roc_auc=0.6153834915997078
# [GAT] epoch=73 loss=0.2382 val_roc_auc=0.616391526661797
# [GAT] epoch=74 loss=0.2526 val_roc_auc=0.6184806428049672
# [GAT] epoch=75 loss=0.2552 val_roc_auc=0.6205405405405405
# [GAT] epoch=76 loss=0.1984 val_roc_auc=0.6228341855368882
# [GAT] epoch=77 loss=0.2255 val_roc_auc=0.6244265887509131
# [GAT] epoch=78 loss=0.2524 val_roc_auc=0.625127830533236
# [GAT] epoch=79 loss=0.2226 val_roc_auc=0.6261796932067202
# [GAT] epoch=80 loss=0.2315 val_roc_auc=0.6259605551497445
# [GAT] epoch=81 loss=0.2103 val_roc_auc=0.6249963476990504
# [GAT] epoch=82 loss=0.2267 val_roc_auc=0.6228049671292915
# [GAT] epoch=83 loss=0.2524 val_roc_auc=0.6213148283418555
# [GAT] epoch=84 loss=0.2118 val_roc_auc=0.6209934258582908
# [GAT] epoch=85 loss=0.2084 val_roc_auc=0.6208035062089117
# [GAT] epoch=86 loss=0.2266 val_roc_auc=0.6214609203798394
# [GAT] epoch=87 loss=0.2332 val_roc_auc=0.6227173119065011
# [GAT] epoch=88 loss=0.1961 val_roc_auc=0.6226296566837107
# [GAT] epoch=89 loss=0.2089 val_roc_auc=0.621563184806428
# [GAT] epoch=90 loss=0.2012 val_roc_auc=0.6212563915266618
# [GAT] epoch=91 loss=0.2121 val_roc_auc=0.6213586559532506
# [GAT] epoch=92 loss=0.1685 val_roc_auc=0.6216800584368153
# [GAT] epoch=93 loss=0.2021 val_roc_auc=0.6216654492330168
# [GAT] epoch=94 loss=0.2130 val_roc_auc=0.6219138056975895
# [GAT] epoch=95 loss=0.1741 val_roc_auc=0.6230387143900658
# [GAT] epoch=96 loss=0.1775 val_roc_auc=0.6234185536888239
# [GAT] epoch=97 loss=0.2000 val_roc_auc=0.6245288531775017
# [GAT] epoch=98 loss=0.1543 val_roc_auc=0.625682980277575
# [GAT] epoch=99 loss=0.1751 val_roc_auc=0.6263257852447042
# [GAT] epoch=100 loss=0.1863 val_roc_auc=0.6265741417092768
# [GAT] Done. Best val roc_auc=0.6266, saved: D:\Shiraz University\HomeWorks\Ostad Moosavi\LinkPrediction\output\models\gat.pt

# %%
print("saved model exists?", best_path.exists())
print("log exists?", log_path.exists())
# Out:
# saved model exists? True
# log exists? True
